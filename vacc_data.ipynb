# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df =pd.read_csv('/Users/naickercreason/dev/DataEngineering.Labs.AirflowProject/vacc CSV data/country_vaccinations.csv', index_col=0)

# %%
print(df)
# Out:
#             iso_code        date  total_vaccinations  people_vaccinated  \
# country
# Afghanistan      AFG  2021-02-22                 0.0                0.0
# Afghanistan      AFG  2021-02-23                 NaN                NaN
# Afghanistan      AFG  2021-02-24                 NaN                NaN
# Afghanistan      AFG  2021-02-25                 NaN                NaN
# Afghanistan      AFG  2021-02-26                 NaN                NaN
# ...              ...         ...                 ...                ...
# Zimbabwe         ZWE  2021-11-25           6513046.0          3738317.0
# Zimbabwe         ZWE  2021-11-26           6544331.0          3757352.0
# Zimbabwe         ZWE  2021-11-27           6560442.0          3765392.0
# Zimbabwe         ZWE  2021-11-28           6568694.0          3770886.0
# Zimbabwe         ZWE  2021-11-29           6586503.0          3782038.0
#
#              people_fully_vaccinated  daily_vaccinations_raw  \
# country
# ...

# %%
df = df.drop(df.columns[[0,3,4,5,6,7,8,9,10,12,13]], axis=1)

# %%
df.dropna(subset=[ 'total_vaccinations' ], inplace=True)

# %%
df
# Out:
#                    date  total_vaccinations  \
# country
# Afghanistan  2021-02-22                 0.0
# Afghanistan  2021-02-28              8200.0
# Afghanistan  2021-03-16             54000.0
# Afghanistan  2021-04-07            120000.0
# Afghanistan  2021-04-22            240000.0
# ...                 ...                 ...
# Zimbabwe     2021-11-25           6513046.0
# Zimbabwe     2021-11-26           6544331.0
# Zimbabwe     2021-11-27           6560442.0
# Zimbabwe     2021-11-28           6568694.0
# Zimbabwe     2021-11-29           6586503.0
#
#                                                       vaccines
# country
# Afghanistan  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# Afghanistan  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# Afghanistan  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# Afghanistan  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# Afghanistan  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# ...

# %%
df.isnull().sum()
# Out:
# date                  0
# total_vaccinations    0
# vaccines              0
# dtype: int64

# %%
# sput = df.loc[df['vaccines'] == 'Sputnik V'].count()[0]
jaj = df.loc[df['vaccines'] == 'Johnson&Johnson']
# sino = df.loc[df['vaccines'] == 'Sinovac'].count()
# mod = df.loc[df['vaccines'] == 'Moderna'].count()
# ox = df.loc[df['vaccines'] == 'Oxford/AstraZeneca'].count()
# pfi = df.loc[df['vaccines'] == 'Pfizer/BioNTech'].count()

# %%
jaj
# Out:
# Empty DataFrame
# Columns: [date, total_vaccinations, vaccines]
# Index: []
