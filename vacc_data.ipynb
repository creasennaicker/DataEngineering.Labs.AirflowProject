# %%
import pandas as pd

# %%
df =pd.read_csv('/Users/naickercreason/dev/DataEngineering.Labs.AirflowProject/archive/country_vaccinations.csv', index_col=0)

# %%
print(df)
# Out:
#             iso_code        date  total_vaccinations  people_vaccinated  \
# country
# Afghanistan      AFG  2021-02-22                 0.0                0.0
# Afghanistan      AFG  2021-02-23                 NaN                NaN
# Afghanistan      AFG  2021-02-24                 NaN                NaN
# Afghanistan      AFG  2021-02-25                 NaN                NaN
# Afghanistan      AFG  2021-02-26                 NaN                NaN
# ...              ...         ...                 ...                ...
# Zimbabwe         ZWE  2021-11-25           6513046.0          3738317.0
# Zimbabwe         ZWE  2021-11-26           6544331.0          3757352.0
# Zimbabwe         ZWE  2021-11-27           6560442.0          3765392.0
# Zimbabwe         ZWE  2021-11-28           6568694.0          3770886.0
# Zimbabwe         ZWE  2021-11-29           6586503.0          3782038.0
#
#              people_fully_vaccinated  daily_vaccinations_raw  \
# country
# ...

# %%
df.shape
# Out:
# (60658, 14)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 60653     Zimbabwe      ZWE  2021-11-25           6513046.0
# 60654     Zimbabwe      ZWE  2021-11-26           6544331.0
# 60655     Zimbabwe      ZWE  2021-11-27           6560442.0
# 60656     Zimbabwe      ZWE  2021-11-28           6568694.0
# 60657     Zimbabwe      ZWE  2021-11-29           6586503.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# ...

# %%
print(df.columns)
# Out:
# Index(['iso_code', 'date', 'total_vaccinations', 'people_vaccinated',
#        'people_fully_vaccinated', 'daily_vaccinations_raw',
#        'daily_vaccinations', 'total_vaccinations_per_hundred',
#        'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
#        'daily_vaccinations_per_million', 'vaccines', 'source_name',
#        'source_website'],
#       dtype='object')

# %%
print(df.rpow)
# Out:
# <bound method flex_arith_method_FRAME.<locals>.f of             iso_code        date  total_vaccinations  people_vaccinated  \
# country
# Afghanistan      AFG  2021-02-22                 0.0                0.0
# Afghanistan      AFG  2021-02-23                 NaN                NaN
# Afghanistan      AFG  2021-02-24                 NaN                NaN
# Afghanistan      AFG  2021-02-25                 NaN                NaN
# Afghanistan      AFG  2021-02-26                 NaN                NaN
# ...              ...         ...                 ...                ...
# Zimbabwe         ZWE  2021-11-25           6513046.0          3738317.0
# Zimbabwe         ZWE  2021-11-26           6544331.0          3757352.0
# Zimbabwe         ZWE  2021-11-27           6560442.0          3765392.0
# Zimbabwe         ZWE  2021-11-28           6568694.0          3770886.0
# Zimbabwe         ZWE  2021-11-29           6586503.0          3782038.0
#
# ...
